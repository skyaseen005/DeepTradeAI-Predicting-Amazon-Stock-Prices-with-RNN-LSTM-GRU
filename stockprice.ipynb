# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense
from tensorflow.keras.optimizers import Adam
import math

# %%
ticker_symbol = "AMZN"
stock_data = yf.download(ticker_symbol, start="2024-01-01", end="2025-10-17")

print(stock_data)
data = stock_data[['Close']].values
print(data)
# Out:
# C:\Users\Yaseen Shaik\AppData\Local\Temp\ipykernel_20984\1430994793.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock_data = yf.download(ticker_symbol, start="2024-01-01", end="2025-10-17")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AMZN        AMZN        AMZN        AMZN      AMZN
# Date
# 2024-01-02  149.929993  152.380005  148.389999  151.539993  47339400
# 2024-01-03  148.470001  151.050003  148.330002  149.199997  49425500
# 2024-01-04  144.570007  147.380005  144.050003  145.589996  56039800
# 2024-01-05  145.240005  146.589996  144.529999  144.690002  45153100
# 2024-01-08  149.100006  149.399994  146.149994  146.740005  46757100
# ...                ...         ...         ...         ...       ...
# 2025-10-10  216.369995  228.250000  216.000000  226.210007  72367500
# 2025-10-13  220.070007  220.679993  217.039993  217.699997  37809700
# 2025-10-14  216.389999  219.320007  212.600006  215.559998  45665600
# 2025-10-15  215.570007  217.710007  212.660004  216.619995  45909500
# 2025-10-16  214.470001  218.589996  212.809998  215.669998  42414600
#
# [450 rows x 5 columns]
# [[149.92999268]
#  [148.47000122]
#  [144.57000732]
#  [145.24000549]
#  [149.1000061 ]
#  [151.36999512]
#  [153.72999573]
#  [155.17999268]
#  [154.61999512]
#  [153.16000366]
#  [151.71000671]
#  [153.5       ]
#  [155.33999634]
#  [154.77999878]
#  [156.02000427]
#  [156.86999512]
#  [157.75      ]
#  [159.11999512]
#  [161.25999451]
#  [159.        ]
#  [155.19999695]
#  [159.27999878]
#  [171.80999756]
#  [170.30999756]
#  [169.1499939 ]
#  [170.52999878]
#  [169.83999634]
#  [174.44999695]
#  [172.33999634]
#  [168.63999939]
#  [170.97999573]
#  [169.80000305]
#  [169.50999451]
#  [167.08000183]
#  [168.58999634]
#  [174.58000183]
#  [174.99000549]
#  [174.72999573]
#  [173.53999329]
#  [173.16000366]
#  [176.75999451]
#  [178.22000122]
#  [177.58000183]
#  [174.11999512]
#  [173.50999451]
#  [176.82000732]
#  [175.3500061 ]
#  [171.96000671]
#  [175.38999939]
#  [176.55999756]
#  [178.75      ]
#  [174.41999817]
#  [174.47999573]
#  [175.8999939 ]
#  [178.1499939 ]
#  [178.1499939 ]
#  [178.86999512]
#  [179.71000671]
#  [178.30000305]
#  [179.83000183]
#  [180.38000488]
#  [180.97000122]
#  [180.69000244]
#  [182.41000366]
#  [180.        ]
#  [185.07000732]
#  [185.19000244]
#  [185.66999817]
#  [185.94999695]
#  [189.05000305]
#  [186.13000488]
#  [183.61999512]
#  [183.32000732]
#  [181.27999878]
#  [179.22000122]
#  [174.63000488]
#  [177.22999573]
#  [179.53999329]
#  [176.58999634]
#  [173.66999817]
#  [179.61999512]
#  [180.96000671]
#  [175.        ]
#  [179.        ]
#  [184.72000122]
#  [186.21000671]
#  [188.69999695]
#  [188.75999451]
#  [188.        ]
#  [189.5       ]
#  [187.47999573]
#  [186.57000732]
#  [187.07000732]
#  [185.99000549]
#  [183.63000488]
#  [184.69999695]
#  [183.53999329]
#  [183.1499939 ]
#  [183.13000488]
#  [181.05000305]
#  [180.75      ]
#  [182.1499939 ]
#  [182.02000427]
#  [179.32000732]
#  [176.44000244]
#  [178.33999634]
#  [179.33999634]
#  [181.27999878]
#  [185.        ]
#  [184.30000305]
#  [187.05999756]
#  [187.22999573]
#  [186.88999939]
#  [183.83000183]
#  [183.66000366]
#  [184.05999756]
#  [182.80999756]
#  [186.1000061 ]
#  [189.08000183]
#  [185.57000732]
#  [186.33999634]
#  [193.61000061]
#  [197.8500061 ]
#  [193.25      ]
#  [197.19999695]
#  [200.        ]
#  [197.58999634]
#  [200.        ]
#  [199.28999329]
#  [199.33999634]
#  [199.78999329]
#  [195.05000305]
#  [194.49000549]
#  [192.72000122]
#  [193.02000427]
#  [187.92999268]
#  [183.75      ]
#  [183.13000488]
#  [182.55000305]
#  [186.41000366]
#  [180.83000183]
#  [179.8500061 ]
#  [182.5       ]
#  [183.19999695]
#  [181.71000671]
#  [186.97999573]
#  [184.07000732]
#  [167.8999939 ]
#  [161.02000427]
#  [161.92999268]
#  [162.77000427]
#  [165.80000305]
#  [166.94000244]
#  [166.80000305]
#  [170.22999573]
#  [170.1000061 ]
#  [177.58999634]
#  [177.05999756]
#  [178.22000122]
#  [178.88000488]
#  [180.11000061]
#  [176.13000488]
#  [177.03999329]
#  [175.5       ]
#  [173.11999512]
#  [170.80000305]
#  [172.11999512]
#  [178.5       ]
#  [176.25      ]
#  [173.33000183]
#  [177.88999939]
#  [171.38999939]
#  [175.3999939 ]
#  [179.55000305]
#  [184.52000427]
#  [187.        ]
#  [186.49000549]
#  [184.88999939]
#  [186.88000488]
#  [186.42999268]
#  [189.86999512]
#  [191.6000061 ]
#  [193.88000488]
#  [193.96000671]
#  [192.52999878]
#  [191.16000366]
#  [187.97000122]
#  [186.33000183]
#  [185.13000488]
#  [184.75999451]
#  [181.96000671]
#  [186.50999451]
#  [180.80000305]
#  [182.72000122]
#  [185.16999817]
#  [186.6499939 ]
#  [188.82000732]
#  [187.53999329]
#  [187.69000244]
#  [186.88999939]
#  [187.52999878]
#  [188.99000549]
#  [189.07000732]
#  [189.69999695]
#  [184.71000671]
#  [186.38000488]
#  [187.83000183]
#  [188.38999939]
#  [190.83000183]
#  [192.72999573]
#  [186.3999939 ]
#  [197.92999268]
#  [195.77999878]
#  [199.5       ]
#  [207.08999634]
#  [210.05000305]
#  [208.17999268]
#  [206.83999634]
#  [208.91000366]
#  [214.1000061 ]
#  [211.47999573]
#  [202.61000061]
#  [201.69999695]
#  [204.61000061]
#  [202.88000488]
#  [198.38000488]
#  [197.11999512]
#  [201.44999695]
#  [207.86000061]
#  [205.74000549]
#  [207.88999939]
#  [210.71000671]
#  [213.44000244]
#  [218.16000366]
#  [220.55000305]
#  [227.02999878]
#  [226.08999634]
#  [225.03999329]
#  [230.25999451]
#  [228.97000122]
#  [227.46000671]
#  [232.92999268]
#  [231.1499939 ]
#  [220.52000427]
#  [223.28999329]
#  [224.91999817]
#  [225.05999756]
#  [229.05000305]
#  [227.05000305]
#  [223.75      ]
#  [221.30000305]
#  [219.38999939]
#  [220.22000122]
#  [224.19000244]
#  [227.61000061]
#  [222.11000061]
#  [222.13000488]
#  [218.94000244]
#  [218.46000671]
#  [217.75999451]
#  [223.3500061 ]
#  [220.66000366]
#  [225.94000244]
#  [230.71000671]
#  [235.00999451]
#  [235.41999817]
#  [234.8500061 ]
#  [235.41999817]
#  [238.1499939 ]
#  [237.07000732]
#  [234.63999939]
#  [237.67999268]
#  [237.41999817]
#  [242.05999756]
#  [236.16999817]
#  [238.83000183]
#  [229.1499939 ]
#  [233.13999939]
#  [232.75999451]
#  [228.92999268]
#  [230.36999512]
#  [228.67999268]
#  [226.6499939 ]
#  [226.63000488]
#  [222.88000488]
#  [216.58000183]
#  [212.71000671]
#  [212.80000305]
#  [214.3500061 ]
#  [208.74000549]
#  [212.27999878]
#  [205.02000427]
#  [203.80000305]
#  [208.36000061]
#  [200.69999695]
#  [199.25      ]
#  [194.53999329]
#  [196.58999634]
#  [198.88999939]
#  [193.88999939]
#  [197.94999695]
#  [195.74000549]
#  [192.82000732]
#  [195.53999329]
#  [194.94999695]
#  [196.21000671]
#  [203.25999451]
#  [205.71000671]
#  [201.13000488]
#  [201.36000061]
#  [192.72000122]
#  [190.25999451]
#  [192.16999817]
#  [196.00999451]
#  [178.41000366]
#  [171.        ]
#  [175.25999451]
#  [170.66000366]
#  [191.1000061 ]
#  [181.22000122]
#  [184.86999512]
#  [182.11999512]
#  [179.58999634]
#  [174.33000183]
#  [172.61000061]
#  [167.32000732]
#  [173.17999268]
#  [180.6000061 ]
#  [186.53999329]
#  [188.99000549]
#  [187.69999695]
#  [187.38999939]
#  [184.41999817]
#  [190.19999695]
#  [189.97999573]
#  [186.3500061 ]
#  [185.00999451]
#  [188.71000671]
#  [192.08000183]
#  [193.05999756]
#  [208.63999939]
#  [211.36999512]
#  [210.25      ]
#  [205.16999817]
#  [205.58999634]
#  [206.16000366]
#  [204.07000732]
#  [201.11999512]
#  [203.1000061 ]
#  [200.99000549]
#  [206.02000427]
#  [204.72000122]
#  [205.69999695]
#  [205.00999451]
#  [206.6499939 ]
#  [205.71000671]
#  [207.22999573]
#  [207.91000366]
#  [213.57000732]
#  [216.97999573]
#  [217.61000061]
#  [213.19999695]
#  [213.24000549]
#  [212.1000061 ]
#  [216.1000061 ]
#  [214.82000732]
#  [212.52000427]
#  [209.69000244]
#  [208.47000122]
#  [212.77000427]
#  [211.99000549]
#  [217.11999512]
#  [223.30000305]
#  [219.38999939]
#  [220.46000671]
#  [219.91999817]
#  [223.41000366]
#  [223.47000122]
#  [219.36000061]
#  [222.53999329]
#  [222.25999451]
#  [225.02000427]
#  [225.69000244]
#  [226.3500061 ]
#  [223.19000244]
#  [223.88000488]
#  [226.13000488]
#  [229.30000305]
#  [227.47000122]
#  [228.28999329]
#  [232.22999573]
#  [231.44000244]
#  [232.78999329]
#  [231.00999451]
#  [230.19000244]
#  [234.11000061]
#  [214.75      ]
#  [211.6499939 ]
#  [213.75      ]
#  [222.30999756]
#  [223.13000488]
#  [222.69000244]
#  [221.30000305]
#  [221.47000122]
#  [224.55999756]
#  [230.97999573]
#  [231.02999878]
#  [231.49000549]
#  [228.00999451]
#  [223.80999756]
#  [221.94999695]
#  [228.83999634]
#  [227.94000244]
#  [228.71000671]
#  [229.11999512]
#  [231.6000061 ]
#  [229.        ]
#  [225.33999634]
#  [225.99000549]
#  [235.67999268]
#  [232.33000183]
#  [235.83999634]
#  [238.24000549]
#  [230.33000183]
#  [229.94999695]
#  [228.1499939 ]
#  [231.42999268]
#  [234.05000305]
#  [231.61999512]
#  [231.22999573]
#  [231.47999573]
#  [227.63000488]
#  [220.71000671]
#  [220.21000671]
#  [218.1499939 ]
#  [219.77999878]
#  [222.16999817]
#  [219.57000732]
#  [220.63000488]
#  [222.41000366]
#  [219.50999451]
#  [220.8999939 ]
#  [221.77999878]
#  [225.22000122]
#  [227.74000549]
#  [216.36999512]
#  [220.07000732]
#  [216.38999939]
#  [215.57000732]
#  [214.47000122]]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

time_step = 60
X, y = [], []
for i in range(time_step, len(scaled_data)):
    X.append(scaled_data[i - time_step:i, 0])
    y.append(scaled_data[i, 0])

X, y = np.array(X), np.array(y)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]
def build_model(model_type, units=100):
    model = Sequential()
    if model_type == "RNN":
        model.add(SimpleRNN(units, input_shape=(X_train.shape[1], 1)))
    elif model_type == "LSTM":
        model.add(LSTM(units, input_shape=(X_train.shape[1], 1)))
    elif model_type == "GRU":
        model.add(GRU(units, input_shape=(X_train.shape[1], 1)))
    else:
        raise ValueError("Invalid model type")

    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model

# %%
models = ["RNN", "LSTM", "GRU"]
results = {}

for m in models:
    print(f"\n🔹 Training {m} Model...")
    model = build_model(m)
    history = model.fit(X_train, y_train, epochs=20, batch_size=16,
                        validation_data=(X_test, y_test), verbose=1)

    y_pred = model.predict(X_test)
    y_pred_rescaled = scaler.inverse_transform(y_pred)
    y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))
    mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
    rmse = math.sqrt(mse)
    mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
    
    results[m] = {'Model': model, 'MSE': mse, 'RMSE': rmse, 'MAE': mae,
                  'Predicted': y_pred_rescaled, 'Actual': y_test_rescaled}
# Out:
# 🔹 Training RNN Model...
# C:\Users\Yaseen Shaik\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0299 - val_loss: 0.0026
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - val_loss: 0.0081
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0042 - val_loss: 0.0023
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - val_loss: 0.0032
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# 🔹 Training LSTM Model...
# Epoch 1/20
# C:\Users\Yaseen Shaik\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0459 - val_loss: 0.0236
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0064 - val_loss: 0.0094
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0049 - val_loss: 0.0059
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0041 - val_loss: 0.0033
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0032 - val_loss: 0.0025
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0026 - val_loss: 0.0025
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# 🔹 Training GRU Model...
# Epoch 1/20
# C:\Users\Yaseen Shaik\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0726 - val_loss: 0.0068
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0074 - val_loss: 0.0029
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0041 - val_loss: 0.0052
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0036 - val_loss: 0.0061
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0019 - val_loss: 0.0019
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000265BAFF8AE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/stepWARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000265BAFF8AE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step

# %%
print("\n Model Comparison Metrics")
comparison = pd.DataFrame([
    {"Model": m, "MSE": r['MSE'], "RMSE": r['RMSE'], "MAE": r['MAE']}
    for m, r in results.items()
])
print(comparison)


plt.figure(figsize=(12,6))
for m in models:
    plt.plot(results[m]['Predicted'], label=f"{m} Predicted")
plt.plot(results['RNN']['Actual'], label='Actual', color='black', linewidth=2)
plt.title("RNN vs LSTM vs GRU - Stock Price Prediction")
plt.xlabel("Days")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
#  Model Comparison Metrics
#   Model        MSE      RMSE       MAE
# 0   RNN  30.174809  5.493160  4.179153
# 1  LSTM  24.118737  4.911083  3.979248
# 2   GRU  17.835310  4.223187  2.989397

# %%
predictions = {}

for m in models:
    model = results[m]['Model']
    last_60_days = scaled_data[-time_step:]
    last_60_days = np.reshape(last_60_days, (1, time_step, 1))
    next_day_scaled = model.predict(last_60_days)
    next_day_price = scaler.inverse_transform(next_day_scaled)
    predictions[m] = next_day_price[0][0]
    print(f" Predicted Next Day Closing Price using {m}: ${next_day_price[0][0]:.2f}")

best_model_name = comparison.sort_values(by="RMSE").iloc[0]['Model']
best_model = results[best_model_name]['Model']

print("\n Best Model Based on RMSE:", best_model_name)
print(f"Predicted Next Day Closing Price for {ticker_symbol} using Best Model ({best_model_name}): ${predictions[best_model_name]:.2f}")

print("\n Summary of All Model Predictions:")
for m, val in predictions.items():
    print(f"{m}: ${val:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#  Predicted Next Day Closing Price using RNN: $218.28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#  Predicted Next Day Closing Price using LSTM: $214.55
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#  Predicted Next Day Closing Price using GRU: $215.25
#
#  Best Model Based on RMSE: GRU
# Predicted Next Day Closing Price for AMZN using Best Model (GRU): $215.25
#
#  Summary of All Model Predictions:
# RNN: $218.28
# LSTM: $214.55
# GRU: $215.25
